# %%
import os, sys
import re
import pandas as pd
import numpy as np
sys.path.insert(0, '../')

# %%
from banglanlp.text.WordProcessor import *

# %%
df = pd.read_csv('../../data/transliteration/dictionary_data/dictionary_extracted_processed.tsv', sep='\t', header=None)

# %%
df.shape
# Out:
# (15657, 2)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (12614, 2)

# %%
df.columns = ['ben','eng']
df
# Out:
#                             ben                         eng
# 0                       ' ই.এম.                    ' I.ema.
# 1                        , পাশে                     , Pashe
# 2                  - আছে হয়েছে               - che hayeche
# 3                    - খোলা শেষ               - Khola shesa
# 4                - গভীর উপবিষ্ট           - Gabhira upabisa
# 5                 - চিম্টি আঘাত               - Cimi aghata
# 6                   - নরম সেদ্ধ            - Narama sed'dha
# 7                  - নিথর শুকনো           - Nithara shukano
# 8             BRIC একটি ব্র্যাক            BRIC ekai bryaka
# 9                       NFL এবং                   NFL ebang
# 10                      PG - 13                     PG - 13
# 11                        PJ এর                      PJ era
# 12     Pooh সহকারে প্রত্যাখ্যান  Pooh sahakare pratyakhyana
# 13               Smarty প্যান্ট                Smarty pyana
# 14                      ZIP কোড                    ZIP koda
# 15                   grad স্কুল                  Grad skula
# 16                 polka বিন্দু                 Polka bindu
# 17                      অ আ ক খ                  A a ka kha
# 18                        অঁ্যা                        Amya
# 20                          অংশ                       Ansha
# 23                     অংশগ্রহণ                Anshagrahana
# 24                 অংশগ্রহণ করা           Anshagrahana kara
# 25                    অংশগ্রাহক                Anshagrahaka
# 26                   অংশভাগ করা             Anshabhaga kara
# 27                      অংশীদার                   Anshidara
# 28                  অংশীদারিত্ব                Anshidaritba
# 29                         অংশু                       Anshu
# 30                        অংশুল                     Anshula
# 31                     অংশুশিরা                  Anshushira
# 32                          অংস                        Ansa
# ...                         ...                         ...
# 15621              হেলাফেলা করা              Helaphela kara
# 15622                হেলিকোপটার                 Helikopaara
# 15623                      হৈচৈ                      Haicai
# 15627             হৈচৈশূন্যভাবে          Haicaishun'yabhabe
# 15628                     হোটেল                       Hoela
# 15629          হোটেলের বড় হলঘর      Hoelera bara halaghara
# 15630                    হোম ঋণ                    Homa rna
# 15631                   হোম পেজ                   Homa peja
# 15632                 হোম প্লেট                   Homa plea
# 15633                   হোম রান                   Homa rana
# 15634                     হোমার                      Homara
# 15635                 হোলিস্টিক                    Holisika
# 15636                     হোস্ট                        Hosa
# 15637                   হ্যাকার                     Hyakara
# 15638                হ্যাঙ্গআউট                 Hyanga'a'ua
# 15639              হ্যাঙ্গার অন                Hyangara ana
# 15640               হ্যাজেল নাট                 Hyajela naa
# 15641                 হ্যানডনোট                  Hyanadanoa
# 15642               হ্যান্ডবুকে                  Hyandabuke
# 15643              হ্যান্ডব্যাগ                 Hyandabyaga
# 15644                হ্যান্ডশেক                 Hyandasheka
# 15645                     হ্যাম                       Hyama
# 15646              হ্যামবার্গার                Hyamabargara
# 15647              হ্যামস্ট্রিং                  Hyamasring
# 15648                    হ্যালো                       Hyalo
# 15649                  হ্যালোইন                   Hyalo'ina
# 15650                     হ্রাস                       Hrasa
# 15652                 হ্রাস করা                  Hrasa kara
# 15653                  হ্রাসকরণ                 Hrasakarana
# 15654               হ্রেষাধ্বনি                 Hresadhbani
#
# [12614 rows x 2 columns]

# %%
df['ben_split'] = df['ben'].str.split(' ')
df['en_split'] = df['eng'].str.split(' ')

# %%
df
# Out:
#                             ben                         eng  \
# 0                       ' ই.এম.                    ' I.ema.
# 1                        , পাশে                     , Pashe
# 2                  - আছে হয়েছে               - che hayeche
# 3                    - খোলা শেষ               - Khola shesa
# 4                - গভীর উপবিষ্ট           - Gabhira upabisa
# 5                 - চিম্টি আঘাত               - Cimi aghata
# 6                   - নরম সেদ্ধ            - Narama sed'dha
# 7                  - নিথর শুকনো           - Nithara shukano
# 8             BRIC একটি ব্র্যাক            BRIC ekai bryaka
# 9                       NFL এবং                   NFL ebang
# 10                      PG - 13                     PG - 13
# 11                        PJ এর                      PJ era
# 12     Pooh সহকারে প্রত্যাখ্যান  Pooh sahakare pratyakhyana
# 13               Smarty প্যান্ট                Smarty pyana
# 14                      ZIP কোড                    ZIP koda
# 15                   grad স্কুল                  Grad skula
# 16                 polka বিন্দু                 Polka bindu
# 17                      অ আ ক খ                  A a ka kha
# 18                        অঁ্যা                        Amya
# 20                          অংশ                       Ansha
# 23                     অংশগ্রহণ                Anshagrahana
# 24                 অংশগ্রহণ করা           Anshagrahana kara
# 25                    অংশগ্রাহক                Anshagrahaka
# 26                   অংশভাগ করা             Anshabhaga kara
# 27                      অংশীদার                   Anshidara
# 28                  অংশীদারিত্ব                Anshidaritba
# 29                         অংশু                       Anshu
# 30                        অংশুল                     Anshula
# 31                     অংশুশিরা                  Anshushira
# 32                          অংস                        Ansa
# ...                         ...                         ...
# 15621              হেলাফেলা করা              Helaphela kara
# 15622                হেলিকোপটার                 Helikopaara
# 15623                      হৈচৈ                      Haicai
# 15627             হৈচৈশূন্যভাবে          Haicaishun'yabhabe
# 15628                     হোটেল                       Hoela
# 15629          হোটেলের বড় হলঘর      Hoelera bara halaghara
# 15630                    হোম ঋণ                    Homa rna
# 15631                   হোম পেজ                   Homa peja
# 15632                 হোম প্লেট                   Homa plea
# 15633                   হোম রান                   Homa rana
# 15634                     হোমার                      Homara
# 15635                 হোলিস্টিক                    Holisika
# 15636                     হোস্ট                        Hosa
# 15637                   হ্যাকার                     Hyakara
# 15638                হ্যাঙ্গআউট                 Hyanga'a'ua
# 15639              হ্যাঙ্গার অন                Hyangara ana
# 15640               হ্যাজেল নাট                 Hyajela naa
# 15641                 হ্যানডনোট                  Hyanadanoa
# 15642               হ্যান্ডবুকে                  Hyandabuke
# 15643              হ্যান্ডব্যাগ                 Hyandabyaga
# 15644                হ্যান্ডশেক                 Hyandasheka
# 15645                     হ্যাম                       Hyama
# 15646              হ্যামবার্গার                Hyamabargara
# 15647              হ্যামস্ট্রিং                  Hyamasring
# 15648                    হ্যালো                       Hyalo
# 15649                  হ্যালোইন                   Hyalo'ina
# 15650                     হ্রাস                       Hrasa
# 15652                 হ্রাস করা                  Hrasa kara
# 15653                  হ্রাসকরণ                 Hrasakarana
# 15654               হ্রেষাধ্বনি                 Hresadhbani
#
#                           ben_split                        en_split
# 0                        [', ই.এম.]                     [', I.ema.]
# 1                         [,, পাশে]                      [,, Pashe]
# 2                  [-, আছে, হয়েছে]               [-, che, hayeche]
# 3                    [-, খোলা, শেষ]               [-, Khola, shesa]
# 4                [-, গভীর, উপবিষ্ট]           [-, Gabhira, upabisa]
# 5                 [-, চিম্টি, আঘাত]               [-, Cimi, aghata]
# 6                   [-, নরম, সেদ্ধ]            [-, Narama, sed'dha]
# 7                  [-, নিথর, শুকনো]           [-, Nithara, shukano]
# 8             [BRIC, একটি, ব্র্যাক]            [BRIC, ekai, bryaka]
# 9                        [NFL, এবং]                    [NFL, ebang]
# 10                      [PG, -, 13]                     [PG, -, 13]
# 11                         [PJ, এর]                       [PJ, era]
# 12     [Pooh, সহকারে, প্রত্যাখ্যান]  [Pooh, sahakare, pratyakhyana]
# 13                [Smarty, প্যান্ট]                 [Smarty, pyana]
# 14                       [ZIP, কোড]                     [ZIP, koda]
# 15                    [grad, স্কুল]                   [Grad, skula]
# 16                  [polka, বিন্দু]                  [Polka, bindu]
# 17                     [অ, আ, ক, খ]                 [A, a, ka, kha]
# 18                          [অঁ্যা]                          [Amya]
# 20                            [অংশ]                         [Ansha]
# 23                       [অংশগ্রহণ]                  [Anshagrahana]
# 24                  [অংশগ্রহণ, করা]            [Anshagrahana, kara]
# 25                      [অংশগ্রাহক]                  [Anshagrahaka]
# 26                    [অংশভাগ, করা]              [Anshabhaga, kara]
# 27                        [অংশীদার]                     [Anshidara]
# 28                    [অংশীদারিত্ব]                  [Anshidaritba]
# 29                           [অংশু]                         [Anshu]
# 30                          [অংশুল]                       [Anshula]
# 31                       [অংশুশিরা]                    [Anshushira]
# 32                            [অংস]                          [Ansa]
# ...                             ...                             ...
# 15621               [হেলাফেলা, করা]               [Helaphela, kara]
# 15622                  [হেলিকোপটার]                   [Helikopaara]
# 15623                        [হৈচৈ]                        [Haicai]
# 15627               [হৈচৈশূন্যভাবে]            [Haicaishun'yabhabe]
# 15628                       [হোটেল]                         [Hoela]
# 15629          [হোটেলের, বড়, হলঘর]      [Hoelera, bara, halaghara]
# 15630                     [হোম, ঋণ]                     [Homa, rna]
# 15631                    [হোম, পেজ]                    [Homa, peja]
# 15632                  [হোম, প্লেট]                    [Homa, plea]
# 15633                    [হোম, রান]                    [Homa, rana]
# 15634                       [হোমার]                        [Homara]
# 15635                   [হোলিস্টিক]                      [Holisika]
# 15636                       [হোস্ট]                          [Hosa]
# 15637                     [হ্যাকার]                       [Hyakara]
# 15638                  [হ্যাঙ্গআউট]                   [Hyanga'a'ua]
# 15639               [হ্যাঙ্গার, অন]                 [Hyangara, ana]
# 15640                [হ্যাজেল, নাট]                  [Hyajela, naa]
# 15641                   [হ্যানডনোট]                    [Hyanadanoa]
# 15642                 [হ্যান্ডবুকে]                    [Hyandabuke]
# 15643                [হ্যান্ডব্যাগ]                   [Hyandabyaga]
# 15644                  [হ্যান্ডশেক]                   [Hyandasheka]
# 15645                       [হ্যাম]                         [Hyama]
# 15646                [হ্যামবার্গার]                  [Hyamabargara]
# 15647                [হ্যামস্ট্রিং]                    [Hyamasring]
# 15648                      [হ্যালো]                         [Hyalo]
# 15649                    [হ্যালোইন]                     [Hyalo'ina]
# 15650                       [হ্রাস]                         [Hrasa]
# 15652                  [হ্রাস, করা]                   [Hrasa, kara]
# 15653                    [হ্রাসকরণ]                   [Hrasakarana]
# 15654                 [হ্রেষাধ্বনি]                   [Hresadhbani]
#
# [12614 rows x 4 columns]

# %%
for i in range(df.shape[0]):
    if len(df['ben_split'][0]) != len(df['en_split'][0]):
        print(i)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (12613, 5)

# %%
bnp = BanglaWordProcessor()
enp = EnglishWordProcessor()

# %%
bnp.puncstr += string.punctuation

# %%
def clean(words, lang):
    res = []
    #print(words)
    for w in words:
        if lang == 'en':
            cw = enp.process(w)
            if cw != '':
                res.append(cw)
        else:
            cw = bnp.process(w)
            if cw != '':
                res.append(cw)
    return res
    

df['ben_split_clean'] = df['ben_split'].apply(clean,lang='bn')
df['en_split_clean'] = df['en_split'].apply(clean,lang='en')

# %%
df
# Out:
#                             ben                         eng  \
# 0                       ' ই.এম.                    ' I.ema.
# 1                        , পাশে                     , Pashe
# 2                  - আছে হয়েছে               - che hayeche
# 3                    - খোলা শেষ               - Khola shesa
# 4                - গভীর উপবিষ্ট           - Gabhira upabisa
# 5                 - চিম্টি আঘাত               - Cimi aghata
# 6                   - নরম সেদ্ধ            - Narama sed'dha
# 7                  - নিথর শুকনো           - Nithara shukano
# 8             BRIC একটি ব্র্যাক            BRIC ekai bryaka
# 9                       NFL এবং                   NFL ebang
# 10                      PG - 13                     PG - 13
# 11                        PJ এর                      PJ era
# 12     Pooh সহকারে প্রত্যাখ্যান  Pooh sahakare pratyakhyana
# 13               Smarty প্যান্ট                Smarty pyana
# 14                      ZIP কোড                    ZIP koda
# 15                   grad স্কুল                  Grad skula
# 16                 polka বিন্দু                 Polka bindu
# 17                      অ আ ক খ                  A a ka kha
# 18                        অঁ্যা                        Amya
# 20                          অংশ                       Ansha
# 23                     অংশগ্রহণ                Anshagrahana
# 24                 অংশগ্রহণ করা           Anshagrahana kara
# 25                    অংশগ্রাহক                Anshagrahaka
# 26                   অংশভাগ করা             Anshabhaga kara
# 27                      অংশীদার                   Anshidara
# 28                  অংশীদারিত্ব                Anshidaritba
# 29                         অংশু                       Anshu
# 30                        অংশুল                     Anshula
# 31                     অংশুশিরা                  Anshushira
# 32                          অংস                        Ansa
# ...                         ...                         ...
# 15621              হেলাফেলা করা              Helaphela kara
# 15622                হেলিকোপটার                 Helikopaara
# 15623                      হৈচৈ                      Haicai
# 15627             হৈচৈশূন্যভাবে          Haicaishun'yabhabe
# 15628                     হোটেল                       Hoela
# 15629          হোটেলের বড় হলঘর      Hoelera bara halaghara
# 15630                    হোম ঋণ                    Homa rna
# 15631                   হোম পেজ                   Homa peja
# 15632                 হোম প্লেট                   Homa plea
# 15633                   হোম রান                   Homa rana
# 15634                     হোমার                      Homara
# 15635                 হোলিস্টিক                    Holisika
# 15636                     হোস্ট                        Hosa
# 15637                   হ্যাকার                     Hyakara
# 15638                হ্যাঙ্গআউট                 Hyanga'a'ua
# 15639              হ্যাঙ্গার অন                Hyangara ana
# 15640               হ্যাজেল নাট                 Hyajela naa
# 15641                 হ্যানডনোট                  Hyanadanoa
# 15642               হ্যান্ডবুকে                  Hyandabuke
# 15643              হ্যান্ডব্যাগ                 Hyandabyaga
# 15644                হ্যান্ডশেক                 Hyandasheka
# 15645                     হ্যাম                       Hyama
# 15646              হ্যামবার্গার                Hyamabargara
# 15647              হ্যামস্ট্রিং                  Hyamasring
# 15648                    হ্যালো                       Hyalo
# 15649                  হ্যালোইন                   Hyalo'ina
# 15650                     হ্রাস                       Hrasa
# 15652                 হ্রাস করা                  Hrasa kara
# 15653                  হ্রাসকরণ                 Hrasakarana
# 15654               হ্রেষাধ্বনি                 Hresadhbani
#
#                           ben_split                        en_split  \
# 0                        [', ই.এম.]                     [', I.ema.]
# 1                         [,, পাশে]                      [,, Pashe]
# 2                  [-, আছে, হয়েছে]               [-, che, hayeche]
# 3                    [-, খোলা, শেষ]               [-, Khola, shesa]
# 4                [-, গভীর, উপবিষ্ট]           [-, Gabhira, upabisa]
# 5                 [-, চিম্টি, আঘাত]               [-, Cimi, aghata]
# 6                   [-, নরম, সেদ্ধ]            [-, Narama, sed'dha]
# 7                  [-, নিথর, শুকনো]           [-, Nithara, shukano]
# 8             [BRIC, একটি, ব্র্যাক]            [BRIC, ekai, bryaka]
# 9                        [NFL, এবং]                    [NFL, ebang]
# 10                      [PG, -, 13]                     [PG, -, 13]
# 11                         [PJ, এর]                       [PJ, era]
# 12     [Pooh, সহকারে, প্রত্যাখ্যান]  [Pooh, sahakare, pratyakhyana]
# 13                [Smarty, প্যান্ট]                 [Smarty, pyana]
# 14                       [ZIP, কোড]                     [ZIP, koda]
# 15                    [grad, স্কুল]                   [Grad, skula]
# 16                  [polka, বিন্দু]                  [Polka, bindu]
# 17                     [অ, আ, ক, খ]                 [A, a, ka, kha]
# 18                          [অঁ্যা]                          [Amya]
# 20                            [অংশ]                         [Ansha]
# 23                       [অংশগ্রহণ]                  [Anshagrahana]
# 24                  [অংশগ্রহণ, করা]            [Anshagrahana, kara]
# 25                      [অংশগ্রাহক]                  [Anshagrahaka]
# 26                    [অংশভাগ, করা]              [Anshabhaga, kara]
# 27                        [অংশীদার]                     [Anshidara]
# 28                    [অংশীদারিত্ব]                  [Anshidaritba]
# 29                           [অংশু]                         [Anshu]
# 30                          [অংশুল]                       [Anshula]
# 31                       [অংশুশিরা]                    [Anshushira]
# 32                            [অংস]                          [Ansa]
# ...                             ...                             ...
# 15621               [হেলাফেলা, করা]               [Helaphela, kara]
# 15622                  [হেলিকোপটার]                   [Helikopaara]
# 15623                        [হৈচৈ]                        [Haicai]
# 15627               [হৈচৈশূন্যভাবে]            [Haicaishun'yabhabe]
# 15628                       [হোটেল]                         [Hoela]
# 15629          [হোটেলের, বড়, হলঘর]      [Hoelera, bara, halaghara]
# 15630                     [হোম, ঋণ]                     [Homa, rna]
# 15631                    [হোম, পেজ]                    [Homa, peja]
# 15632                  [হোম, প্লেট]                    [Homa, plea]
# 15633                    [হোম, রান]                    [Homa, rana]
# 15634                       [হোমার]                        [Homara]
# 15635                   [হোলিস্টিক]                      [Holisika]
# 15636                       [হোস্ট]                          [Hosa]
# 15637                     [হ্যাকার]                       [Hyakara]
# 15638                  [হ্যাঙ্গআউট]                   [Hyanga'a'ua]
# 15639               [হ্যাঙ্গার, অন]                 [Hyangara, ana]
# 15640                [হ্যাজেল, নাট]                  [Hyajela, naa]
# 15641                   [হ্যানডনোট]                    [Hyanadanoa]
# 15642                 [হ্যান্ডবুকে]                    [Hyandabuke]
# 15643                [হ্যান্ডব্যাগ]                   [Hyandabyaga]
# 15644                  [হ্যান্ডশেক]                   [Hyandasheka]
# 15645                       [হ্যাম]                         [Hyama]
# 15646                [হ্যামবার্গার]                  [Hyamabargara]
# 15647                [হ্যামস্ট্রিং]                    [Hyamasring]
# 15648                      [হ্যালো]                         [Hyalo]
# 15649                    [হ্যালোইন]                     [Hyalo'ina]
# 15650                       [হ্রাস]                         [Hrasa]
# 15652                  [হ্রাস, করা]                   [Hrasa, kara]
# 15653                    [হ্রাসকরণ]                   [Hrasakarana]
# 15654                 [হ্রেষাধ্বনি]                   [Hresadhbani]
#
#                     ben_split_clean                  en_split_clean
# 0                             [ইএম]                          [iema]
# 1                            [পাশে]                         [pashe]
# 2                     [আছে, হয়েছে]                  [che, hayeche]
# 3                       [খোলা, শেষ]                  [khola, shesa]
# 4                   [গভীর, উপবিষ্ট]              [gabhira, upabisa]
# 5                    [চিম্টি, আঘাত]                  [cimi, aghata]
# 6                      [নরম, সেদ্ধ]                [narama, seddha]
# 7                     [নিথর, শুকনো]              [nithara, shukano]
# 8             [BRIC, একটি, ব্র্যাক]            [BRIC, ekai, bryaka]
# 9                        [NFL, এবং]                    [NFL, ebang]
# 10                         [PG, 13]                        [PG, 13]
# 11                         [PJ, এর]                       [PJ, era]
# 12     [Pooh, সহকারে, প্রত্যাখ্যান]  [pooh, sahakare, pratyakhyana]
# 13                [Smarty, প্যান্ট]                 [smarty, pyana]
# 14                       [ZIP, কোড]                     [ZIP, koda]
# 15                    [grad, স্কুল]                   [grad, skula]
# 16                  [polka, বিন্দু]                  [polka, bindu]
# 17                     [অ, আ, ক, খ]                 [A, a, ka, kha]
# 18                          [অঁ্যা]                          [amya]
# 20                            [অংশ]                         [ansha]
# 23                       [অংশগ্রহণ]                  [anshagrahana]
# 24                  [অংশগ্রহণ, করা]            [anshagrahana, kara]
# 25                      [অংশগ্রাহক]                  [anshagrahaka]
# 26                    [অংশভাগ, করা]              [anshabhaga, kara]
# 27                        [অংশীদার]                     [anshidara]
# 28                    [অংশীদারিত্ব]                  [anshidaritba]
# 29                           [অংশু]                         [anshu]
# 30                          [অংশুল]                       [anshula]
# 31                       [অংশুশিরা]                    [anshushira]
# 32                            [অংস]                          [ansa]
# ...                             ...                             ...
# 15621               [হেলাফেলা, করা]               [helaphela, kara]
# 15622                  [হেলিকোপটার]                   [helikopaara]
# 15623                        [হৈচৈ]                        [haicai]
# 15627               [হৈচৈশূন্যভাবে]             [haicaishunyabhabe]
# 15628                       [হোটেল]                         [hoela]
# 15629          [হোটেলের, বড়, হলঘর]      [hoelera, bara, halaghara]
# 15630                     [হোম, ঋণ]                     [homa, rna]
# 15631                    [হোম, পেজ]                    [homa, peja]
# 15632                  [হোম, প্লেট]                    [homa, plea]
# 15633                    [হোম, রান]                    [homa, rana]
# 15634                       [হোমার]                        [homara]
# 15635                   [হোলিস্টিক]                      [holisika]
# 15636                       [হোস্ট]                          [hosa]
# 15637                     [হ্যাকার]                       [hyakara]
# 15638                  [হ্যাঙ্গআউট]                     [hyangaaua]
# 15639               [হ্যাঙ্গার, অন]                 [hyangara, ana]
# 15640                [হ্যাজেল, নাট]                  [hyajela, naa]
# 15641                   [হ্যানডনোট]                    [hyanadanoa]
# 15642                 [হ্যান্ডবুকে]                    [hyandabuke]
# 15643                [হ্যান্ডব্যাগ]                   [hyandabyaga]
# 15644                  [হ্যান্ডশেক]                   [hyandasheka]
# 15645                       [হ্যাম]                         [hyama]
# 15646                [হ্যামবার্গার]                  [hyamabargara]
# 15647                [হ্যামস্ট্রিং]                    [hyamasring]
# 15648                      [হ্যালো]                         [hyalo]
# 15649                    [হ্যালোইন]                      [hyaloina]
# 15650                       [হ্রাস]                         [hrasa]
# 15652                  [হ্রাস, করা]                   [hrasa, kara]
# 15653                    [হ্রাসকরণ]                   [hrasakarana]
# 15654                 [হ্রেষাধ্বনি]                   [hresadhbani]
#
# [12613 rows x 6 columns]

# %%
for i in range(df.shape[0]):
    if len(df['ben_split_clean'][0]) != len(df['en_split_clean'][0]):
        print(i)

# %%
data = []
for row in df[['ben_split_clean','en_split_clean']].values:
    
    for i in range(len(row[0])):
        if not row[0][i].isalnum():
            data.append([row[0][i],row[1][i]])

# %%
df_2 = pd.DataFrame(data, columns=['ben','eng'])

# %%
df_2.to_csv('../../data/transliteration/dictionary_data/Dictionary_data_cleaned.tsv',sep='\t',header=None, index=False)
